# %% [markdown]
# # 04 - Coverage Model Training
#
# This notebook trains the coverage prediction model.

# %%
import pandas as pd
import numpy as np
from src.models.train_coverage import train_coverage_model

# Load training data
# X_train = pd.read_csv('../data/processed/X_train.csv')
# y_train = pd.read_csv('../data/processed/y_train.csv')
