# %% [markdown]
# # 01 - Exploratory Data Analysis
#
# This notebook performs exploratory data analysis on the datasets.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
# df = pd.read_csv('../data/raw/your_data.csv')
